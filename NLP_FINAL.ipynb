# %% [markdown]
# <a href="https://colab.research.google.com/github/KuzAlexey/FMM/blob/main/NLP_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Strings** in Python are a collection of characters and are one of the most commonly used data types. They can be enclosed in single quotes (') or double quotes (") for one line of text, and triple quotes (''' or """) for longer pieces and f-strings (to be discussed later on).

# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.util import ngrams
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer

# Download necessary NLTK resources
nltk.download('stopwords')
nltk.download('punkt')

# Function to preprocess text: Remove punctuation and stopwords
def preprocess_text(text):
    # Remove punctuation
    text = ''.join([char for char in text if char not in string.punctuation])

    # Tokenize the text into words
    words = nltk.word_tokenize(text.lower())  # Convert to lowercase to ensure case-insensitivity

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    return words

# Function to count word frequency
def count_words(text):
    words = preprocess_text(text)
    word_freq = Counter(words)
    return word_freq

# Function to count n-grams frequency
def count_ngrams(text, n=2):
    words = preprocess_text(text)
    n_grams = ngrams(words, n)
    ngram_freq = Counter(n_grams)
    return ngram_freq

# Example usage
# Count word frequency
word_count = count_words(text)
print("Word Frequency:")
print(word_count)

# Count bigram frequency (2-grams)
bigram_count = count_ngrams(text, n=2)
print("\nBigram Frequency (2-grams):")
print(bigram_count)

# Count trigram frequency (3-grams)
trigram_count = count_ngrams(text, n=3)
print("\nTrigram Frequency (3-grams):")
print(trigram_count)

# Alternatively, using CountVectorizer from sklearn to count word frequencies
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform([text])
word_freq_sklearn = dict(zip(vectorizer.get_feature_names_out(), X.toarray().flatten()))
print("\nWord Frequency using sklearn CountVectorizer:")
print(word_freq_sklearn)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Word Frequency:
# ...

# %%
def read_file_to_string(file_path):
    try:
        # Open the file in read mode and read the content
        with open(file_path, 'r', encoding='utf-8') as file:
            file_content = file.read()
        return file_content
    except FileNotFoundError:
        print(f"The file at {file_path} was not found.")
        return None
    except IOError:
        print(f"An error occurred while reading the file at {file_path}.")
        return None

# Example usage
file_path = '/content/sample_data/MERGED.txt'  # Replace with your file path
text = read_file_to_string(file_path)

# %%
from matplotlib import pyplot as plt
import numpy as np

Language = ['algorithm', 'parallel', 'vortex',
        'particles', 'tree', 'method']
data = [218, 212, 168, 146, 145, 141]

fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = Language)

plt.show()

# %%
from collections import Counter
import string

def count_word_frequencies(text):
    # Remove punctuation from the text
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Convert the text to lowercase to ensure case-insensitive counting
    text = text.lower()

    # Split the text into words based on whitespace
    words = text.split()

    # Use Counter to count the frequency of each word
    word_frequencies = Counter(words)

    return word_frequencies


word_frequencies = count_word_frequencies(text)

# Print the word frequencies
cnt = 10
w_cnt = []
for word, count in word_frequencies.items():
    w_cnt.append([count, str(word)])
    # print(f"{word}: {count}")
w_cnt = sorted(w_cnt)[1100:1110]
print(w_cnt)
# Out:
# [[1, 'fig1'], [1, 'fig2'], [1, 'fig3'], [1, 'filling'], [1, 'financial'], [1, 'find'], [1, 'finitevolume'], [1, 'firstlastipvsunistuttgartde'], [1, 'fit'], [1, 'fix']]

# %% [markdown]
# In the Python programming language, **variables** may be given names (or identifiers) that consist of letters (from the set "a-z, A-Z"), digits (from the set "0-9"), and underscores ("_"). However, the name must begin with a letter or an underscore. It should be noted that variable names are case-sensitive; therefore, "myVar" and "myvar" would be considered distinct variables. Furthermore, it is recommended that variable names be meaningful and descriptive, as this enhances code readability. The = operator may be used to assign a value to a variable.
#
# Strings support several **operators** that allow you to perform operations such as concatenation, repetition, etc.
